# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.color import rgb2gray
from skimage import data
import Image

from skimage.data import camera
from skimage.filters import roberts, sobel, scharr, prewitt

# %%
#Image conversion into grey scale
img=np.array(Image.open('Normalization_Try_Cropped_Resized/r_c_223240.jpg'))
img_gray = rgb2gray(img)

edge_roberts = roberts(img_gray)
edge_sobel = sobel(img_gray)

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts Edge Detection')

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

ax[2].imshow(img, cmap=plt.cm.gray)
ax[2].set_title('Original image')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
x, y = np.ogrid[:100, :100]
# Rotation-invariant image with different spatial frequencies
img = np.exp(1j * np.hypot(x, y)**1.3 / 20.).real

img=np.array(Image.open('Normalization_Try_Cropped_Resized/r_c_223240.jpg'))
img_gray = rgb2gray(img)

edge_sobel = sobel(img_gray)
edge_scharr = scharr(img_gray)
edge_prewitt = prewitt(img_gray)

diff_scharr_prewitt = edge_scharr - edge_prewitt
diff_scharr_sobel = edge_scharr - edge_sobel
max_diff = np.max(np.maximum(diff_scharr_prewitt, diff_scharr_sobel))

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original image')

ax[1].imshow(edge_scharr, cmap=plt.cm.gray)
ax[1].set_title('Scharr Edge Detection')

ax[2].imshow(diff_scharr_prewitt, cmap=plt.cm.gray, vmax=max_diff)
ax[2].set_title('Scharr - Prewitt')

ax[3].imshow(diff_scharr_sobel, cmap=plt.cm.gray, vmax=max_diff)
ax[3].set_title('Scharr - Sobel')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Second Example

# %%
#Image conversion into grey scale
img=np.array(Image.open('Normalization_Try_Cropped_Resized/r_c_223243.jpg'))
img_gray = rgb2gray(img)

edge_roberts = roberts(img_gray)
edge_sobel = sobel(img_gray)

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts Edge Detection')

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

ax[2].imshow(img, cmap=plt.cm.gray)
ax[2].set_title('Original image')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Third Example

# %%
#Image conversion into grey scale
img=np.array(Image.open('Normalization_Try_Cropped_Resized/r_c_223244.jpg'))
img_gray = rgb2gray(img)

edge_roberts = roberts(img_gray)
edge_sobel = sobel(img_gray)

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts Edge Detection')

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

ax[2].imshow(img, cmap=plt.cm.gray)
ax[2].set_title('Original image')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # No Food Example

# %%
#Image conversion into grey scale
img=np.array(Image.open('Normalization_Try_Cropped_Resized/r_c_22325.jpg'))
img_gray = rgb2gray(img)

edge_roberts = roberts(img_gray)
edge_sobel = sobel(img_gray)

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts Edge Detection')

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

ax[2].imshow(img, cmap=plt.cm.gray)
ax[2].set_title('Original image')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()
