# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

# %%
import tensorflow as tf
from sklearn import cross_validation
from sklearn import metrics as mt
from sklearn import utils as ut
import gc
import csv
import numpy as np
import os.path as path
from os import listdir
from PIL import Image

# %%
def dataSplit(array, size):
    split = [element['id'] for element in ut.shuffle(array, n_samples=size, random_state=37)]
    return [element for element in array if element['id'] in split], [element for element in array if element['id'] not in split]

def splitPositiveNegative(array, positiveClass):
    return [element for element in array if positiveClass in element['labels_raw']], [element for element in array if positiveClass not in element['labels_raw']]

def proportionalDataSplit(positive, negative, positiveSize, size):
    positiveSize = np.floor(positiveSize*size).astype(int)
    negativeSize = (size-positiveSize).astype(int)
    
    positiveSplit = [element['id'] for element in ut.shuffle(positive, n_samples=positiveSize, random_state=37)]
    negativeSplit = [element['id'] for element in ut.shuffle(negative, n_samples=negativeSize, random_state=37)]
    
    return [element for element in positive if element['id'] in positiveSplit], [element for element in positive if element['id'] not in positiveSplit], [element for element in negative if element['id'] in negativeSplit], [element for element in negative if element['id'] not in negativeSplit]
                     
def dataAndLabels(array, negative = None):
    if negative is None:
        return [np.array(Image.open(path.join(imagesDir, element['id']))) for element in array], [element['labels'] for element in array]
    elif type(negative) is type([]):
        return [np.array(Image.open(path.join(imagesDir, element['id']))) for element in array] + [np.array(Image.open(path.join(imagesDir, element['id']))) for element in negative], [[0,1]]*len(array) + [[1,0]]*len(negative)
    else:
        return

# %%
with open('./photo_to_levels.csv') as f:
    food_to_label = []
    for row in csv.DictReader(f, skipinitialspace=True):
        element = {}
        for k, v in row.items():
            if k == "id":
                element['id'] = str(v) + ".jpg"
            elif k == "labels":
                labels_raw = np.array(str(v).split(' '))
                labels = [0] * 9
                labels_int = []
                try:
                    for lb in labels_raw:
                        labels[int(str(lb))] = 1
                        labels_int.append(int(lb))
                except ValueError:
                    print "Failure with value", lb, "labels lenght", len(labels_raw), "content:", v
                element['labels'] = labels
                element['labels_raw'] = labels_int
            else :
                print "No idea what you just passed!"
        
        if len(element['labels_raw']) is not 0:
            food_to_label.append(element)
        else:
            print "Picture", element['id'], "has no labels and is being ignored!"

if len(set([element['id'] for element in food_to_label])) != len(food_to_label):
    print('something\'s wrong!')
# Out:
# Failure with value  labels lenght 1 content:
# Picture 329580.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 253479.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 142477.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 346344.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 80447.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 184631.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 115457.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 358078.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 457783.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 169841.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 303684.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 468383.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 253468.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 283131.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 128589.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 33198.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 272798.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 55286.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 408086.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 240908.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 277233.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 287700.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 209060.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 336384.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 453692.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 466550.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 432807.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 390068.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 344856.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 97688.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 229848.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 92828.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 446597.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 333868.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 27838.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 83210.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 201251.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 52686.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 59643.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 112943.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 6067.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 145487.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 248251.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 145281.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 186321.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 300991.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 471256.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 288850.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 184178.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 99385.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 462595.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 378447.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 318362.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 373775.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 70928.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 365381.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 400625.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 374347.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 440483.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 38338.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 300373.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 288548.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 33193.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 471588.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 197763.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 21605.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 202561.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 259255.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 337284.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 30863.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 6921.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 300707.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 426415.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 127676.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 129653.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 221405.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 188785.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 442081.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 215501.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 380028.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 402128.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 125414.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 303535.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 309098.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 142910.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 233355.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 462976.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 67313.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 336962.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 175399.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 171702.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 103814.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 437370.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 66467.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 315853.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 173976.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 410974.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 255456.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 381760.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 153297.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 394765.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 70015.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 363378.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 114142.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 160918.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 306753.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 418361.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 449173.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 433186.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 121666.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 59844.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 351858.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 348274.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 105402.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 117781.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 144824.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 193424.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 249933.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 142433.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 453355.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 112882.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 396628.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 198270.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 238266.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 470302.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 447070.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 404390.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 156444.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 9537.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 155335.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 133594.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 31608.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 404185.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 233845.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 355078.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 460478.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 426323.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 282983.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 161894.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 338983.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 276424.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 162491.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 342722.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 391906.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 271930.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 397849.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 405378.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 261028.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 107953.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 458381.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 390632.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 461938.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 10970.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 391313.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 284919.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 23272.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 200443.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 283922.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 268419.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 109708.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 469359.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 21036.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 30432.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 183903.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 80914.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 281169.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 328516.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 22344.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 338494.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 401488.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 271937.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 73656.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 364023.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 314262.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 150807.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 297282.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 289089.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 147672.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 68833.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 98189.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 1764.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 64426.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 1319.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 56514.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 439634.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 408035.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 311719.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 30554.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 366052.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 86257.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 96556.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 241196.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 185072.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 217001.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 41029.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 72912.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 174924.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 348587.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 351828.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 350203.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 338692.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 77215.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 291036.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 79907.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 97752.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 249899.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 282414.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 161506.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 415748.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 415546.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 214269.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 173403.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 408809.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 17174.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 394378.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 261853.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 463216.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 417271.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 339294.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 447593.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 260991.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 100871.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 142392.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 445756.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 434983.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 45123.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 198526.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 383564.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 393589.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 168710.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 168263.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 300019.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 292413.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 134049.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 208360.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 247143.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 424736.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 100179.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 37925.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 98815.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 394423.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 266061.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 220608.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 318963.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 394467.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 368487.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 249689.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 435246.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 22389.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 134510.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 397443.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 399693.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 314897.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 40032.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 437512.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 223922.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 172277.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 79793.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 163212.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 455327.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 251392.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 421112.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 163370.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 371967.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 261087.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 106561.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 91792.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 262832.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 146041.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 100563.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 216969.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 387703.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 340495.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 217433.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 38337.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 388991.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 89304.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 388558.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 381788.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 421803.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 153733.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 421399.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 346474.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 404673.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 45470.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 432334.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 139925.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 52544.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 400573.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 388184.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 460717.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 359331.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 266711.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 221266.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 54515.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 372246.jpg has no labels and is being ignored!
# Failure with value  labels lenght 1 content:
# Picture 38994.jpg has no labels and is being ignored!

# %%
proportions = []
for lb in range(9):
    l = len([element for element in food_to_label if lb in element['labels_raw']])/float(len(food_to_label))
    print "Label", lb, "is present at", int(l*100), "% with respect to all other labels"
    proportions.append(l)
# Out:
# Label 0 is present at 22 % with respect to all other labels
# Label 1 is present at 59 % with respect to all other labels
# Label 2 is present at 64 % with respect to all other labels
# Label 3 is present at 48 % with respect to all other labels
# Label 4 is present at 42 % with respect to all other labels
# Label 5 is present at 73 % with respect to all other labels
# Label 6 is present at 77 % with respect to all other labels
# Label 7 is present at 37 % with respect to all other labels
# Label 8 is present at 50 % with respect to all other labels

# %%
# Data dir
imagesDir = './data/train_photos_norm_100/train_photos_norm_100'

# Filter out images which might not be present in the folder but are present in the csv file
files = [f for f in listdir(imagesDir) if path.isfile(path.join(imagesDir, f))]
food_to_label = [element for element in food_to_label if element['id'] in files]

# leave out images that have more than 3 classes --> information content is very low
food_to_label = [element for element in food_to_label if len(element['labels_raw']) < 6]

del files[:]
gc.collect()

print "The new length of the data is", len(food_to_label)

# Parameters
test_size = 500
learning_rate_start= .001
training_size = 100
training_iters = 8000
dropout = 0.75 # Dropout, probability to keep units

# Network Parameters
# !! Images: 100x100 RGB = 100, 100, 3
w, h, channels = [100, 100, 3]
n_classes = 2
print "Width, Height and channels:", w, h, channels, ". Number of classes:", n_classes

# tf Graph input
x = tf.placeholder(tf.float32, [None, w, h, channels], name="x")
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)
# Out:
# The new length of the data is 130651
# Width, Height and channels: 100 100 3 . Number of classes: 2

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)
    print "PLEASE MODIFY WD1 TO", conv2.get_shape().as_list()[1], "*",conv2.get_shape().as_list()[2], "*64"

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
sdev= 0.01
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.truncated_normal([5, 5, channels, 32], stddev=sdev), name="wc1"),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.truncated_normal([5, 5, 32, 64], stddev=sdev), name="wc2"),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.truncated_normal([25*25*64, 1024], stddev=sdev), name="wd1"),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.truncated_normal([1024, n_classes], stddev=sdev), name="outw")
}

biases = {
    'bc1': tf.Variable(tf.truncated_normal([32], stddev=sdev), name="bc1"),
    'bc2': tf.Variable(tf.truncated_normal([64], stddev=sdev), name="bc2"),
    'bd1': tf.Variable(tf.truncated_normal([1024], stddev=sdev), name="bd1"),
    'out': tf.Variable(tf.truncated_normal([n_classes], stddev=sdev, name="outd"))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))

# optimizer without adapted learning_rate
#optimizer = tf.train.AdamOptimizerOptimizer(learning_rate=learning_rate).minimize(cost)

#optimizer with adapted learning_rate
step = tf.Variable(0, trainable=False)
rate = tf.train.exponential_decay(learning_rate_start, step, 1, 0.9999)

optimizer = tf.train.AdamOptimizer(rate).minimize(cost, global_step=step)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
y_p = tf.argmax(pred, 1)


# Gives an array of arrays, where each position represents % of belonging to respective classs. Eg: a[0.34, 0.66] --> class 0 : 34%, class 1: 66%
# classes = tf.nn.softmax(pred)
classes = tf.nn.softmax(pred)


def label_class(x):
    for i in range(0,len(x)):
        print i, ":", x[i]

# Initializing the variables
init = tf.initialize_all_variables()
# Out:
# PLEASE MODIFY WD1 TO 25 * 25 *64

# %%
# save the models
saveDir = './tensorflow/one_against_all_6'

# %%
for currentLabel in range(len(proportions)):
    saver = tf.train.Saver()
    
    print "Training model for", currentLabel, "which is represented by", proportions[currentLabel]
    positive, negative = splitPositiveNegative(food_to_label, currentLabel)
    
    # Get some test samples
    test1, positive, test0, negative = proportionalDataSplit(positive, negative, proportions[currentLabel], test_size)
    
    positiveSize = np.floor(proportions[currentLabel]*training_size).astype(int)
    negativeSize = (training_size-positiveSize).astype(int)
    
    # Launch the graph
    with tf.Session() as sess:
        sess.run(init)

        # Keep training until reach max iterations
        for epoch in range(training_iters):
            if len(positive) < positiveSize or len(negative) < negativeSize:
                del ix[:]
                del iy[:]
                del batch1[:]
                del batch0[:]
                break
            # Fit training using batch data
            print "Loading batch...",
            batch1, positive, batch0, negative = proportionalDataSplit(positive, negative, proportions[currentLabel], training_size)
            ix, iy = dataAndLabels(batch1, batch0)
            print "bactch loaded!"

            print "Running optimizer...",
            sess.run(optimizer, feed_dict={x: ix, y: iy, keep_prob: 1.})
            print "done!"
            # Compute average loss
            #loss, acc = sess.run([cost, accuracy], feed_dict={x: ix, y: iy, keep_prob: 1.})
            # Display logs per epoch step
            #print "Iter " + str(epoch) + ", Minibatch Loss= " + \
            #           "{:.6f}".format(loss) + ", Training Accuracy= " + \
            #          "{:.5f}".format(acc)
            del ix[:]
            del iy[:]
            del batch1[:]
            del batch0[:]
        print "Optimization Finished!"
        
        save_path = saver.save(sess, path.join(saveDir, "label-" + str(currentLabel) + ".ckpt"))
        print("Model saved in file: %s" % save_path)

        runs = 0
        acc = 0.
        y_pred = []
        class_pred = []
        test = test1 + test0
        y_test = [[0,1]]*len(test1) + [[1,0]]*len(test0)
        for i in range(0, test_size, 30):
            if i+30 < test_size:
                x_test, _ = dataAndLabels(test[i:i+30])
                val_accuracy, y_pred_i, cls = sess.run([accuracy, y_p, classes], feed_dict={x: x_test, y: y_test[i:i+30], keep_prob: 1.})
            else:
                x_test, _ = dataAndLabels(test[i:])
                val_accuracy, y_pred_i, cls = sess.run([accuracy, y_p, classes], feed_dict={x: x_test, y: y_test[i:], keep_prob: 1.})
            acc += val_accuracy
            y_pred.extend(y_pred_i)
            class_pred.extend(cls)
            runs += 1
            print "Partial testing accuracy:", acc/runs

        #metrics
        print "Validation accuracy:", acc/runs
        y_true = np.argmax(y_test,1)
        print "Precision for each class:"
        label_class(mt.precision_score(y_true, y_pred, average=None))
        print "Recall for each class:"
        label_class(mt.recall_score(y_true, y_pred, average=None))
        print "F1_score for each class:"
        label_class(mt.f1_score(y_true, y_pred, average=None))
        print "confusion_matrix"
        print mt.confusion_matrix(y_true, y_pred)
        fpr, tpr, tresholds = mt.roc_curve(y_true, y_pred)
# Out:
# Training model for 0 which is represented by 0.228331450255
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# ...
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Loading batch... bactch loaded!
# Running optimizer... done!
# Optimization Finished!
# Model saved in file: ./tensorflow/one_against_all_6/label-8.ckpt
# Partial testing accuracy: 0.699999988079
# Partial testing accuracy: 0.616666674614
# Partial testing accuracy: 0.644444445769
# Partial testing accuracy: 0.666666671634
# Partial testing accuracy: 0.660000002384
# Partial testing accuracy: 0.666666666667
# Partial testing accuracy: 0.671428569726
# Partial testing accuracy: 0.658333331347
# Partial testing accuracy: 0.648148145941
# Partial testing accuracy: 0.633333331347
# Partial testing accuracy: 0.642424242063
# Partial testing accuracy: 0.650000000993
# Partial testing accuracy: 0.651282053727
# Partial testing accuracy: 0.645238097225
# Partial testing accuracy: 0.646666669846
# Partial testing accuracy: 0.652083337307
# Partial testing accuracy: 0.654901963823
# Validation accuracy: 0.654901963823
# Precision for each class:
# 0 : 0.648
# 1 : 0.66
# Recall for each class:
# 0 : 0.655870445344
# 1 : 0.652173913043
# F1_score for each class:
# 0 : 0.651911468813
# 1 : 0.65606361829
# confusion_matrix
# [[162  85]
#  [ 88 165]]

# %%
for i in range(len(y_test)):
    print "For", i, "as", y_test[i]
    for j in range(2):
        print "\t", j, "@", class_pred[i][j]*100
    print "\n"
